# %% [markdown]
# # 📦 Loading the basic libraries required

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# ## step 1. 📥📁 Loading the training data for processing

# %%
df=pd.read_csv("ANN_Challenge_Train_v1.csv")
df.describe()
# Out:
#           Sensor_1     Sensor_2     Sensor_3     Sensor_4     Sensor_5  \
# count  3000.000000  3000.000000  3000.000000  3000.000000  2850.000000
# mean      0.282350    -0.034925     0.386357   100.071609    10.033604
# std       0.157657     0.975404     0.945288    29.898577     5.024830
# min       0.003445    -3.179870    -3.001669    40.090238    -6.440784
# 25%       0.152271    -0.698720    -0.128212    74.223633     6.666244
# 50%       0.260383    -0.048992     0.405202   100.206000    10.017329
# 75%       0.394636     0.627771     1.008773   124.319254    13.603624
# max       0.788990     3.280300     3.103201   179.859989    28.432520
#
#           Sensor_6        Fault
# count  3000.000000  3000.000000
# mean      1.498571     0.200000
# std       1.516585     0.400067
# min       0.000945     0.000000
# 25%       0.426473     0.000000
# 50%       0.992030     0.000000
# 75%       2.095111     0.000000
# max      12.117814     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sensor_1  3000 non-null   float64
#  1   Sensor_2  3000 non-null   float64
#  2   Sensor_3  3000 non-null   float64
#  3   Sensor_4  3000 non-null   float64
#  4   Sensor_5  2850 non-null   float64
#  5   Sensor_6  3000 non-null   float64
#  6   Fault     3000 non-null   int64
# dtypes: float64(6), int64(1)
# memory usage: 164.2 KB

# %% [markdown]
# ### No. of nulls in the given features (sensor_5): 150

# %%
df.isnull().sum()
# Out:
# Sensor_1      0
# Sensor_2      0
# Sensor_3      0
# Sensor_4      0
# Sensor_5    150
# Sensor_6      0
# Fault         0
# dtype: int64

# %% [markdown]
# ## 📊 Step 2: Visualization of Plots

# %% [markdown]
# ### 🔍 Fault Label Distribution

# %%
# Bar plot of fault and non-faulty machines
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Fault', hue='Fault', palette='Set2', legend=False)
plt.title("Fault Label Distribution")
plt.xticks([0, 1], ['Normal (0)', 'Faulty (1)'])
plt.ylabel("Count")
plt.xlabel("Fault Label")
plt.show()

# Show normalized class distribution
df['Fault'].value_counts(normalize=True)
# Out:
# Fault
# 0    0.8
# 1    0.2
# Name: proportion, dtype: float64

# %% [markdown]
# ### 📊 Sensor Distribution Plots

# %% [markdown]
# #### 💾 Storing the initial sensor columns before feature engineering

# %%
# Identify all sensor columns
sensor_cols = [col for col in df.columns if col.startswith('Sensor_')]

# Create a new column as the product of all sensor values row-wise
df['Sensor_Product'] = df[sensor_cols].prod(axis=1)
sensor_cols = [col for col in df.columns if col.startswith('Sensor_')]

# %% [markdown]
# #### 1. plot of orginal features

# %%
# Set the number of plots per row
n_cols = 3
n_rows = -(-len(sensor_cols) // n_cols)  # number of rows

plt.figure(figsize=(n_cols * 5, n_rows * 3))

for i, col in enumerate(sensor_cols):
    plt.subplot(n_rows, n_cols, i + 1)
    sns.histplot(data=df, x=col, hue='Fault', kde=True, bins=40, element="step", palette='Set2', legend=False)
    plt.title(f"{col}")
    plt.xlabel('')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 🛠️ Storing the Engineered Sensor Features

# %%
df['Sensor_1_minus_2'] = df['Sensor_1'] - df['Sensor_2']
df['Sensor_2_minus_3'] = df['Sensor_2'] - df['Sensor_3']
# delta

df['Sensor_1_div_2'] = df['Sensor_1'] / (df['Sensor_2'] + 1e-6)
# ratio

df['Sensor_1_sq'] = df['Sensor_1'] ** 2
df['Sensor_1_x_Sensor_2'] = df['Sensor_1'] * df['Sensor_2']
# polynomial

df['Sensor_product_log'] = np.log1p(df['Sensor_Product'])
# step cures fixing

for col in sensor_cols:
    df[f'{col}_zscore'] = (df[col] - df[col].mean()) / df[col].std()


sensor_cols = [col for col in df.columns if col.startswith('Sensor_')]

# %% [markdown]
# #### 2. plot after engineered Sensor features

# %%
# Set the number of plots per row
n_cols = 4
n_rows = -(-len(sensor_cols) // n_cols)  # Ceiling division to get the number of rows

plt.figure(figsize=(n_cols * 5, n_rows * 3))  # Customize the overall figure size

for i, col in enumerate(sensor_cols):
    plt.subplot(n_rows, n_cols, i + 1)
    sns.histplot(data=df, x=col, hue='Fault', kde=True, bins=40, element="step", palette='Set2', legend=False)
    plt.title(f"{col}")
    plt.xlabel('')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📈 Sensor Correlation Heatmap

# %%
def heatmap(sensor_cols):# printing heatmap
    plt.figure(figsize=(8, 6))
    corr = df[sensor_cols + ['Fault']].corr()
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", square=True)
    plt.title("Correlation Matrix (Sensors + Fault)")
    plt.show()

# %% [markdown]
# #### selecting the best features

# %%
best_features = [
    'Sensor_1_zscore', 'Sensor_2_zscore', 'Sensor_3_zscore',
    'Sensor_4_zscore', 'Sensor_5_zscore', 'Sensor_6_zscore',
     'Sensor_1_x_Sensor_2',
    'Sensor_1_sq', 'Sensor_product_log',
]

# %% [markdown]
# #### Heatmap

# %%
heatmap(best_features)

# %% [markdown]
# ## 🧪 Step 3: Preparing Data for Training and Testing

# %% [markdown]
# ### 🧼 Fixing Empty/Null Values with Median Imputation

# %%
train_data_imputed = df.copy()
for col in best_features:
    train_data_imputed[col] = train_data_imputed[col].fillna(train_data_imputed[col].median())

# %% [markdown]
# ### ✅ Feature Selection

# %%
selected_features={
    'Sensor_3_zscore',
    'Sensor_2_zscore',
    'Sensor_5_zscore',
    'Sensor_1_x_Sensor_2',
}

# Select features for scaling
X = train_data_imputed[best_features]
y = train_data_imputed['Fault']

# %% [markdown]
# ### 🔄 Feature Scaling|

# %%
# Initialize scaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### 🔀 Train-Test Split

# %%
# Train-validation split with stratification
X_train, X_val, y_train, y_val = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# %% [markdown]
# ### ⚖️ Handling the Imbalance of Class Weights

# %%
# Compute class weights to handle imbalance
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

# %% [markdown]
# ## 🤖 Step 4: Model Training and Testing

# %% [markdown]
# ### 🏋️ Model Training

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Define the model
model = Sequential([
    Dense(512, activation='relu', kernel_regularizer=l2(0.001), input_shape=(X_resampled.shape[1],)),
    BatchNormalization(),
    Dropout(0.2),

    Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.15),

    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.1),

    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.05),

    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),

    Dense(1, activation='sigmoid')  # Binary classification
])

# Compile with Adam optimizer
model.compile(
    optimizer = Adam(learning_rate=0.001),
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

model.summary()
# Out:
# C:\Users\Jeetu Modi\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 512)                 │           5,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 183,297 (716.00 KB)
#  Trainable params: 181,505 (709.00 KB)
#  Non-trainable params: 1,792 (7.00 KB)

# %% [markdown]
# ### ⏱️ Callbacks During Model Training

# %%
# Callbacks
early_stop = EarlyStopping(patience=20, restore_best_weights=True, monitor='val_loss')
reduce_lr = ReduceLROnPlateau(patience=2, factor=0.5, verbose=1)

# Train
history = model.fit(
    X_resampled, y_resampled,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.6699 - loss: 1.2573 - val_accuracy: 0.6200 - val_loss: 1.2920 - learning_rate: 0.0100
# Epoch 2/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8172 - loss: 1.1006 - val_accuracy: 0.7650 - val_loss: 1.1723 - learning_rate: 0.0100
# Epoch 3/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8155 - loss: 1.0445 - val_accuracy: 0.8000 - val_loss: 1.0891 - learning_rate: 0.0100
# Epoch 4/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8398 - loss: 0.9840 - val_accuracy: 0.8483 - val_loss: 1.0035 - learning_rate: 0.0100
# Epoch 5/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8400 - loss: 0.9673 - val_accuracy: 0.8117 - val_loss: 1.0255 - learning_rate: 0.0100
# Epoch 6/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8303 - loss: 0.9406 - val_accuracy: 0.8517 - val_loss: 0.8969 - learning_rate: 0.0100
# Epoch 7/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8346 - loss: 0.9147 - val_accuracy: 0.8433 - val_loss: 0.8909 - learning_rate: 0.0100
# Epoch 8/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8441 - loss: 0.8720 - val_accuracy: 0.8583 - val_loss: 0.8326 - learning_rate: 0.0100
# Epoch 9/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8447 - loss: 0.8514 - val_accuracy: 0.8433 - val_loss: 0.8649 - learning_rate: 0.0100
# Epoch 10/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8557 - loss: 0.8265 - val_accuracy: 0.8467 - val_loss: 0.8131 - learning_rate: 0.0100
# Epoch 11/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8489 - loss: 0.8000 - val_accuracy: 0.8433 - val_loss: 0.8315 - learning_rate: 0.0100
# Epoch 12/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8520 - loss: 0.7923 - val_accuracy: 0.8550 - val_loss: 0.7896 - learning_rate: 0.0100
# Epoch 13/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8554 - loss: 0.7564 - val_accuracy: 0.8600 - val_loss: 0.7397 - learning_rate: 0.0100
# Epoch 14/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8620 - loss: 0.7350 - val_accuracy: 0.8367 - val_loss: 0.7642 - learning_rate: 0.0100
# Epoch 15/100
# 113/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8476 - loss: 0.7240
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8485 - loss: 0.7227 - val_accuracy: 0.8483 - val_loss: 0.7455 - learning_rate: 0.0100
# Epoch 16/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8570 - loss: 0.7065 - val_accuracy: 0.8450 - val_loss: 0.7331 - learning_rate: 0.0050
# Epoch 17/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8613 - loss: 0.6853 - val_accuracy: 0.8583 - val_loss: 0.7072 - learning_rate: 0.0050
# Epoch 18/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8725 - loss: 0.6617 - val_accuracy: 0.8533 - val_loss: 0.7028 - learning_rate: 0.0050
# Epoch 19/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8550 - loss: 0.6752 - val_accuracy: 0.8517 - val_loss: 0.7157 - learning_rate: 0.0050
# Epoch 20/100
# 116/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8600 - loss: 0.6661
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8603 - loss: 0.6655 - val_accuracy: 0.8450 - val_loss: 0.7031 - learning_rate: 0.0050
# Epoch 21/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8681 - loss: 0.6369 - val_accuracy: 0.8567 - val_loss: 0.6876 - learning_rate: 0.0025
# Epoch 22/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8743 - loss: 0.6346 - val_accuracy: 0.8467 - val_loss: 0.7012 - learning_rate: 0.0025
# Epoch 23/100
# 119/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8830 - loss: 0.6091
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8829 - loss: 0.6093 - val_accuracy: 0.8417 - val_loss: 0.7027 - learning_rate: 0.0025
# Epoch 24/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8784 - loss: 0.6126 - val_accuracy: 0.8633 - val_loss: 0.6770 - learning_rate: 0.0012
# Epoch 25/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8659 - loss: 0.6330 - val_accuracy: 0.8600 - val_loss: 0.6712 - learning_rate: 0.0012
# Epoch 26/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8731 - loss: 0.6158 - val_accuracy: 0.8550 - val_loss: 0.6843 - learning_rate: 0.0012
# Epoch 27/100
# 117/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8639 - loss: 0.6312
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8642 - loss: 0.6309 - val_accuracy: 0.8567 - val_loss: 0.6752 - learning_rate: 0.0012
# Epoch 28/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8859 - loss: 0.5938 - val_accuracy: 0.8583 - val_loss: 0.6740 - learning_rate: 6.2500e-04
# Epoch 29/100
# 119/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8725 - loss: 0.6139
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8726 - loss: 0.6138 - val_accuracy: 0.8650 - val_loss: 0.6729 - learning_rate: 6.2500e-04
# Epoch 30/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8780 - loss: 0.5957 - val_accuracy: 0.8633 - val_loss: 0.6740 - learning_rate: 3.1250e-04
# Epoch 31/100
# 115/120 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8851 - loss: 0.5966
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8849 - loss: 0.5969 - val_accuracy: 0.8600 - val_loss: 0.6749 - learning_rate: 3.1250e-04
# Epoch 32/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8921 - loss: 0.5775 - val_accuracy: 0.8667 - val_loss: 0.6718 - learning_rate: 1.5625e-04
# Epoch 33/100
# 115/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8756 - loss: 0.6138
# Epoch 33: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8758 - loss: 0.6131 - val_accuracy: 0.8650 - val_loss: 0.6715 - learning_rate: 1.5625e-04
# Epoch 34/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8742 - loss: 0.6079 - val_accuracy: 0.8650 - val_loss: 0.6709 - learning_rate: 7.8125e-05
# Epoch 35/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8894 - loss: 0.5891 - val_accuracy: 0.8650 - val_loss: 0.6723 - learning_rate: 7.8125e-05
# Epoch 36/100
# 118/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8713 - loss: 0.5969
# Epoch 36: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8715 - loss: 0.5968 - val_accuracy: 0.8650 - val_loss: 0.6724 - learning_rate: 7.8125e-05
# Epoch 37/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8885 - loss: 0.5821 - val_accuracy: 0.8650 - val_loss: 0.6712 - learning_rate: 3.9062e-05
# Epoch 38/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8863 - loss: 0.5897
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8863 - loss: 0.5896 - val_accuracy: 0.8650 - val_loss: 0.6712 - learning_rate: 3.9062e-05
# Epoch 39/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8924 - loss: 0.5839 - val_accuracy: 0.8650 - val_loss: 0.6716 - learning_rate: 1.9531e-05
# Epoch 40/100
# 116/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8822 - loss: 0.5999
# Epoch 40: ReduceLROnPlateau reducing learning rate to 9.765624781721272e-06.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8822 - loss: 0.5995 - val_accuracy: 0.8650 - val_loss: 0.6710 - learning_rate: 1.9531e-05
# Epoch 41/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8872 - loss: 0.5871 - val_accuracy: 0.8650 - val_loss: 0.6719 - learning_rate: 9.7656e-06
# Epoch 42/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8697 - loss: 0.6272
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.882812390860636e-06.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8697 - loss: 0.6270 - val_accuracy: 0.8650 - val_loss: 0.6718 - learning_rate: 9.7656e-06
# Epoch 43/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8801 - loss: 0.5942 - val_accuracy: 0.8650 - val_loss: 0.6712 - learning_rate: 4.8828e-06
# Epoch 44/100
# 117/120 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8866 - loss: 0.5892
# Epoch 44: ReduceLROnPlateau reducing learning rate to 2.441406195430318e-06.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8866 - loss: 0.5893 - val_accuracy: 0.8650 - val_loss: 0.6733 - learning_rate: 4.8828e-06
# Epoch 45/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8837 - loss: 0.5871 - val_accuracy: 0.8650 - val_loss: 0.6698 - learning_rate: 2.4414e-06
# Epoch 46/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8818 - loss: 0.5995 - val_accuracy: 0.8667 - val_loss: 0.6698 - learning_rate: 2.4414e-06
# Epoch 47/100
# 114/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8826 - loss: 0.5946
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.220703097715159e-06.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8827 - loss: 0.5947 - val_accuracy: 0.8650 - val_loss: 0.6707 - learning_rate: 2.4414e-06
# Epoch 48/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8759 - loss: 0.6039 - val_accuracy: 0.8650 - val_loss: 0.6714 - learning_rate: 1.2207e-06
# Epoch 49/100
# 118/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8765 - loss: 0.6169
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.103515488575795e-07.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8765 - loss: 0.6167 - val_accuracy: 0.8650 - val_loss: 0.6714 - learning_rate: 1.2207e-06
# Epoch 50/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8880 - loss: 0.5910 - val_accuracy: 0.8617 - val_loss: 0.6739 - learning_rate: 6.1035e-07
# Epoch 51/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8787 - loss: 0.6135
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.0517577442878974e-07.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8787 - loss: 0.6134 - val_accuracy: 0.8650 - val_loss: 0.6712 - learning_rate: 6.1035e-07
# Epoch 52/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8764 - loss: 0.6066 - val_accuracy: 0.8617 - val_loss: 0.6728 - learning_rate: 3.0518e-07
# Epoch 53/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8963 - loss: 0.5651 - val_accuracy: 0.8667 - val_loss: 0.6686 - learning_rate: 3.0518e-07
# Epoch 54/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8815 - loss: 0.6051 - val_accuracy: 0.8650 - val_loss: 0.6709 - learning_rate: 3.0518e-07
# Epoch 55/100
# 115/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8886 - loss: 0.5712
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.5258788721439487e-07.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8881 - loss: 0.5720 - val_accuracy: 0.8650 - val_loss: 0.6715 - learning_rate: 3.0518e-07
# Epoch 56/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8914 - loss: 0.5810 - val_accuracy: 0.8650 - val_loss: 0.6704 - learning_rate: 1.5259e-07
# Epoch 57/100
# 118/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8889 - loss: 0.5847
# Epoch 57: ReduceLROnPlateau reducing learning rate to 7.629394360719743e-08.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8886 - loss: 0.5851 - val_accuracy: 0.8650 - val_loss: 0.6705 - learning_rate: 1.5259e-07
# Epoch 58/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8842 - loss: 0.5965 - val_accuracy: 0.8650 - val_loss: 0.6715 - learning_rate: 7.6294e-08
# Epoch 59/100
# 118/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8826 - loss: 0.5887
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.814697180359872e-08.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8825 - loss: 0.5890 - val_accuracy: 0.8650 - val_loss: 0.6700 - learning_rate: 7.6294e-08
# Epoch 60/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8961 - loss: 0.5734 - val_accuracy: 0.8650 - val_loss: 0.6703 - learning_rate: 3.8147e-08
# Epoch 61/100
# 119/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8855 - loss: 0.5879
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.907348590179936e-08.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8855 - loss: 0.5880 - val_accuracy: 0.8650 - val_loss: 0.6701 - learning_rate: 3.8147e-08
# Epoch 62/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8817 - loss: 0.5892 - val_accuracy: 0.8650 - val_loss: 0.6697 - learning_rate: 1.9073e-08
# Epoch 63/100
# 112/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8783 - loss: 0.6000
# Epoch 63: ReduceLROnPlateau reducing learning rate to 9.53674295089968e-09.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8787 - loss: 0.5999 - val_accuracy: 0.8650 - val_loss: 0.6703 - learning_rate: 1.9073e-08
# Epoch 64/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8828 - loss: 0.6006 - val_accuracy: 0.8650 - val_loss: 0.6713 - learning_rate: 9.5367e-09
# Epoch 65/100
# 118/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8805 - loss: 0.5994
# Epoch 65: ReduceLROnPlateau reducing learning rate to 4.76837147544984e-09.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8804 - loss: 0.5995 - val_accuracy: 0.8650 - val_loss: 0.6687 - learning_rate: 9.5367e-09
# Epoch 66/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8930 - loss: 0.5735 - val_accuracy: 0.8650 - val_loss: 0.6710 - learning_rate: 4.7684e-09
# Epoch 67/100
# 114/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8948 - loss: 0.5799
# Epoch 67: ReduceLROnPlateau reducing learning rate to 2.38418573772492e-09.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8942 - loss: 0.5806 - val_accuracy: 0.8667 - val_loss: 0.6702 - learning_rate: 4.7684e-09
# Epoch 68/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8756 - loss: 0.5973 - val_accuracy: 0.8650 - val_loss: 0.6705 - learning_rate: 2.3842e-09
# Epoch 69/100
# 114/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8840 - loss: 0.5924
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.19209286886246e-09.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8838 - loss: 0.5930 - val_accuracy: 0.8650 - val_loss: 0.6711 - learning_rate: 2.3842e-09
# Epoch 70/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8945 - loss: 0.5727 - val_accuracy: 0.8650 - val_loss: 0.6719 - learning_rate: 1.1921e-09
# Epoch 71/100
# 115/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8743 - loss: 0.6227
# Epoch 71: ReduceLROnPlateau reducing learning rate to 5.9604643443123e-10.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8745 - loss: 0.6218 - val_accuracy: 0.8650 - val_loss: 0.6704 - learning_rate: 1.1921e-09
# Epoch 72/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8800 - loss: 0.5933 - val_accuracy: 0.8650 - val_loss: 0.6698 - learning_rate: 5.9605e-10
# Epoch 73/100
# 114/120 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8809 - loss: 0.5972
# Epoch 73: ReduceLROnPlateau reducing learning rate to 2.98023217215615e-10.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8810 - loss: 0.5971 - val_accuracy: 0.8650 - val_loss: 0.6712 - learning_rate: 5.9605e-10

# %% [markdown]
# ### 🧪 Model Testing

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, roc_auc_score
import numpy as np
import matplotlib.pyplot as plt

# Predict probabilities
y_val_probs = model.predict(X_val).ravel()

# Try multiple thresholds to find best F1
thresholds = np.linspace(0.1, 0.9, 81)
f1_scores = [f1_score(y_val, y_val_probs >= t) for t in thresholds]

# Find best threshold
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

# Plot F1 vs Threshold
plt.figure(figsize=(10, 4))
plt.plot(thresholds, f1_scores, label='F1 Score')
plt.axvline(best_threshold, color='red', linestyle='--', label=f'Best Threshold: {best_threshold:.2f}')
plt.title("F1 Score vs Threshold")
plt.xlabel("Threshold")
plt.ylabel("F1 Score")
plt.legend()
plt.grid(True)
plt.show()

# Final classification with best threshold
y_val_pred = (y_val_probs >= best_threshold).astype(int)

# Show metrics
print(f"🔍 Best Threshold: {best_threshold:.2f}")
print(f"✅ F1 Score:       {f1_score(y_val, y_val_pred):.4f}")
print(f"📌 Precision:      {precision_score(y_val, y_val_pred):.4f}")
print(f"📌 Recall:         {recall_score(y_val, y_val_pred):.4f}")
print(f"📌 ROC AUC:        {roc_auc_score(y_val, y_val_probs):.4f}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 🔍 Best Threshold: 0.62
# ✅ F1 Score:       0.7361
# 📌 Precision:      0.6310
# 📌 Recall:         0.8833
# 📌 ROC AUC:        0.8939

# %%
# 📍 Predictions on Test Data

# %%
# Load test data
test_data = pd.read_csv("ANN_Challenge_Test_with_ID_v1.csv")

# Sensor columns
sensor_cols = [col for col in test_data.columns if col.startswith("Sensor_")]

# Sensor product
test_data['Sensor_Product'] = test_data[sensor_cols].prod(axis=1)

# Delta features
test_data['Sensor_1_minus_2'] = test_data['Sensor_1'] - test_data['Sensor_2']
test_data['Sensor_2_minus_3'] = test_data['Sensor_2'] - test_data['Sensor_3']

# Ratio feature
test_data['Sensor_1_div_2'] = test_data['Sensor_1'] / (test_data['Sensor_2'] + 1e-6)

# Polynomial features
test_data['Sensor_1_sq'] = test_data['Sensor_1'] ** 2
test_data['Sensor_1_x_Sensor_2'] = test_data['Sensor_1'] * test_data['Sensor_2']

# Log transform (safe version)
sensor_product_clipped = test_data['Sensor_Product'].clip(lower=0)
test_data['Sensor_product_log'] = np.log1p(sensor_product_clipped)

# Z-score features using train_data_imputed mean & std
for col in sensor_cols + ['Sensor_Product']:
    mean = train_data_imputed[col].mean()
    std = train_data_imputed[col].std()
    test_data[f'{col}_zscore'] = (test_data[col] - mean) / std

# Ensure all training features are present
for col in best_features:
    if col not in test_data.columns:
        test_data[col] = 0  # or fill with median later

# Fill missing with training medians
for col in best_features:
    test_data[col] = test_data[col].fillna(train_data_imputed[col].median())

# Final transformation using trained scaler
X_test = scaler.transform(test_data[best_features])


# Predict probabilities on hidden test set
test_probs = model.predict(X_test).ravel()

# Apply tuned threshold
test_preds = (test_probs >= best_threshold).astype(int)

# Create submission DataFrame
submission = pd.DataFrame({
    'ID': test_data['ID'],
    'Predicted_Label': test_preds
})

# Save submission file
submission.to_csv("model.csv", index=False)

print("Submission file saved as: model.csv")
